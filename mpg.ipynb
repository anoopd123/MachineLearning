# %% [markdown]
# # Exploratory Data Service

# %%
import pandas as pd

# %%
df = pd.read_csv("mpg.csv")

# %%
df.describe()
# Out:
#               MPG   Cylinders  Engine Disp  Horsepower       Weight  \
# count  392.000000  392.000000   392.000000  392.000000   392.000000
# mean    23.445918    5.471939   194.411990  104.469388  2977.584184
# std      7.805007    1.705783   104.644004   38.491160   849.402560
# min      9.000000    3.000000    68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000   105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000   151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000   275.750000  126.000000  3614.750000
# max     46.600000    8.000000   455.000000  230.000000  5140.000000
#
#        Accelerate        Year
# count  392.000000  392.000000
# mean    15.541327   75.979592
# std      2.758864    3.683737
# min      8.000000   70.000000
# 25%     13.775000   73.000000
# 50%     15.500000   76.000000
# 75%     17.025000   79.000000
# max     24.800000   82.000000

# %%
df.shape
# Out:
# (392, 8)

# %%
df.sum()
# Out:
# MPG                                                       9190.8
# Cylinders                                                   2145
# Engine Disp                                              76209.5
# Horsepower                                                 40952
# Weight                                                   1167213
# Accelerate                                                6092.2
# Year                                                       29784
# Origin         AmericanAmericanAmericanAmericanAmericanAmeric...
# dtype: object

# %%
df.isna().sum()
# Out:
# MPG            0
# Cylinders      0
# Engine Disp    0
# Horsepower     0
# Weight         0
# Accelerate     0
# Year           0
# Origin         0
# dtype: int64

# %%
df.head()
# Out:
#     MPG  Cylinders  Engine Disp  Horsepower  Weight  Accelerate  Year  \
# 0  15.0          8        390.0         190    3850         8.5    70
# 1  21.0          6        199.0          90    2648        15.0    70
# 2  18.0          6        199.0          97    2774        15.5    70
# 3  16.0          8        304.0         150    3433        12.0    70
# 4  14.0          8        455.0         225    3086        10.0    70
#
#      Origin
# 0  American
# 1  American
# 2  American
# 3  American
# 4  American

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MPG          392 non-null    float64
#  1   Cylinders    392 non-null    int64
#  2   Engine Disp  392 non-null    float64
#  3   Horsepower   392 non-null    int64
#  4   Weight       392 non-null    int64
#  5   Accelerate   392 non-null    float64
#  6   Year         392 non-null    int64
#  7   Origin       392 non-null    object
# dtypes: float64(3), int64(4), object(1)
# memory usage: 24.6+ KB

# %%
df.describe()
# Out:
#               MPG   Cylinders  Engine Disp  Horsepower       Weight  \
# count  392.000000  392.000000   392.000000  392.000000   392.000000
# mean    23.445918    5.471939   194.411990  104.469388  2977.584184
# std      7.805007    1.705783   104.644004   38.491160   849.402560
# min      9.000000    3.000000    68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000   105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000   151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000   275.750000  126.000000  3614.750000
# max     46.600000    8.000000   455.000000  230.000000  5140.000000
#
#        Accelerate        Year
# count  392.000000  392.000000
# mean    15.541327   75.979592
# std      2.758864    3.683737
# min      8.000000   70.000000
# 25%     13.775000   73.000000
# 50%     15.500000   76.000000
# 75%     17.025000   79.000000
# max     24.800000   82.000000

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 387    False
# 388    False
# 389    False
# 390    False
# 391    False
# Length: 392, dtype: bool

# %%
df.MPG.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df.MPG.hist()
# Out:
# <Axes: >

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'MPG'}>,
#         <Axes: title={'center': 'Cylinders'}>,
#         <Axes: title={'center': 'Engine Disp'}>],
#        [<Axes: title={'center': 'Horsepower'}>,
#         <Axes: title={'center': 'Weight'}>,
#         <Axes: title={'center': 'Accelerate'}>],
#        [<Axes: title={'center': 'Year'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
df.Accelerate.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df.Origin.unique()
# Out:
# array(['American', 'European', 'Japanese'], dtype=object)

# %%
df.Origin.value_counts()
# Out:
# Origin
# American    245
# Japanese     79
# European     68
# Name: count, dtype: int64

# %%
df.Origin.value_counts().plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ### Which Cars are most fuel efficient

# %%
df.groupby('Origin').mean()
# Out:
#                 MPG  Cylinders  Engine Disp  Horsepower       Weight  \
# Origin
# American  20.033469   6.277551   247.512245  119.048980  3372.489796
# European  27.602941   4.161765   109.632353   80.558824  2433.470588
# Japanese  30.450633   4.101266   102.708861   79.835443  2221.227848
#
#           Accelerate       Year
# Origin
# American   14.990204  75.591837
# European   16.794118  75.676471
# Japanese   16.172152  77.443038

# %%
df.groupby('Origin').mean().MPG
# Out:
# Origin
# American    20.033469
# European    27.602941
# Japanese    30.450633
# Name: MPG, dtype: float64

# %%
df.groupby('Origin').mean().MPG.plot.bar()
# Out:
# <Axes: xlabel='Origin'>

# %% [markdown]
# ### Correlation

# %%
help(df.corr)
# Out:
# Help on method corr in module pandas.core.frame:
#
# corr(method: 'CorrelationMethod' = 'pearson', min_periods: 'int' = 1, numeric_only: 'bool' = False) -> 'DataFrame' method of pandas.core.frame.DataFrame instance
#     Compute pairwise correlation of columns, excluding NA/null values.
#
#     Parameters
#     ----------
#     method : {'pearson', 'kendall', 'spearman'} or callable
#         Method of correlation:
#
#         * pearson : standard correlation coefficient
#         * kendall : Kendall Tau correlation coefficient
#         * spearman : Spearman rank correlation
#         * callable: callable with input two 1d ndarrays
#             and returning a float. Note that the returned matrix from corr
#             will have 1 along the diagonals and will be symmetric
#             regardless of the callable's behavior.
#     min_periods : int, optional
#         Minimum number of observations required per pair of columns
# ...

# %%
df.corr(numeric_only = True)
# Out:
#                   MPG  Cylinders  Engine Disp  Horsepower    Weight  \
# MPG          1.000000  -0.777618    -0.805127   -0.778427 -0.832244
# Cylinders   -0.777618   1.000000     0.950823    0.842983  0.897527
# Engine Disp -0.805127   0.950823     1.000000    0.897257  0.932994
# Horsepower  -0.778427   0.842983     0.897257    1.000000  0.864538
# Weight      -0.832244   0.897527     0.932994    0.864538  1.000000
# Accelerate   0.423329  -0.504683    -0.543800   -0.689196 -0.416839
# Year         0.580541  -0.345647    -0.369855   -0.416361 -0.309120
#
#              Accelerate      Year
# MPG            0.423329  0.580541
# Cylinders     -0.504683 -0.345647
# Engine Disp   -0.543800 -0.369855
# Horsepower    -0.689196 -0.416361
# Weight        -0.416839 -0.309120
# Accelerate     1.000000  0.290316
# Year           0.290316  1.000000

# %%
df.corr(numeric_only = True).MPG
# Out:
# MPG            1.000000
# Cylinders     -0.777618
# Engine Disp   -0.805127
# Horsepower    -0.778427
# Weight        -0.832244
# Accelerate     0.423329
# Year           0.580541
# Name: MPG, dtype: float64

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr(numeric_only = True))
# Out:
# <Axes: >

# %% [markdown]
# ### Correlation using Scatter plot

# %%
df.plot.scatter(x='Weight', y='MPG') #Correlation of two columns data with the scatter visualization
# Out:
# <Axes: xlabel='Weight', ylabel='MPG'>

# %%
df.plot.scatter(x='Accelerate', y='MPG') #Correlation of two columns data with the scatter visualization
# Out:
# <Axes: xlabel='Accelerate', ylabel='MPG'>

# %% [markdown]
# ### Box Plots

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
df.MPG.plot.box(vert = False)
# Out:
# <Axes: >

# %%
df.Accelerate.plot.box(vert = False)
# Out:
# <Axes: >

# %%
df.boxplot(column = 'MPG', by= 'Origin')
# Out:
# <Axes: title={'center': 'MPG'}, xlabel='Origin'>

# %%
df.boxplot(column = 'MPG', by= 'Year')
# Out:
# <Axes: title={'center': 'MPG'}, xlabel='Year'>

# %%
df_loans = pd.read_csv("loan_clean1.csv")

# %%
df_loans.describe
# Out:
# <bound method NDFrame.describe of      Unnamed: 0   Loan_ID  Gender Married Dependents     Education  \
# 0             0  LP001002    MALE      No          0      Graduate
# 1             1  LP001003    MALE     Yes          1      Graduate
# 2             2  LP001005    MALE     Yes          0      Graduate
# 3             3  LP001006    MALE     Yes          0  Not Graduate
# 4             4  LP001008    MALE      No          0      Graduate
# ..          ...       ...     ...     ...        ...           ...
# 613         620  LP002978  FEMALE      No          0      Graduate
# 614         621  LP002979    MALE     Yes         3+      Graduate
# 615         622  LP002983    MALE     Yes          1      Graduate
# 616         623  LP002984    MALE     Yes          2      Graduate
# 617         624  LP002990  FEMALE      No          0      Graduate
#
#     Self_Employed  ApplicantIncome  CoapplicantIncome  Loan_Amount_Term  \
# ...

# %%
df_loans.boxplot(column = 'LoanAmountINR', by= 'Gender')
# Out:
# <Axes: title={'center': 'LoanAmountINR'}, xlabel='Gender'>

# %%
df_loans.boxplot(column = 'LoanAmountINR', by= 'Education')
# Out:
# <Axes: title={'center': 'LoanAmountINR'}, xlabel='Education'>
